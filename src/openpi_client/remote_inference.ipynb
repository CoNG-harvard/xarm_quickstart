# %%
from openpi_client import image_tools
from openpi_client import websocket_client_policy

# Outside of episode loop, initialize the policy client.
# Point to the host and port of the policy server (localhost and 8000 are the defaults).
client = websocket_client_policy.WebsocketClientPolicy(host="10.243.49.215", port=8000)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[1], line 6
#       2 from openpi_client import websocket_client_policy
#       4 # Outside of episode loop, initialize the policy client.
#       5 # Point to the host and port of the policy server (localhost and 8000 are the defaults).
# ----> 6 client = websocket_client_policy.WebsocketClientPolicy(host="10.243.49.215", port=8000)
#
# File ~/PycharmProjects/openpi/packages/openpi-client/src/openpi_client/websocket_client_policy.py:27, in WebsocketClientPolicy.__init__(self, host, port, api_key)
#      25 self._packer = msgpack_numpy.Packer()
#      26 self._api_key = api_key
# ---> 27 self._ws, self._server_metadata = self._wait_for_server()
#
# File ~/PycharmProjects/openpi/packages/openpi-client/src/openpi_client/websocket_client_policy.py:37, in WebsocketClientPolicy._wait_for_server(self)
#      35 try:
#      36     headers = {"Authorization": f"Api-Key {self._api_key}"} if self._api_key else None
# ---> 37     conn = websockets.sync.client.connect(
#      38         self._uri, compression=None, max_size=None, additional_headers=headers
#      39     )
#      40     metadata = msgpack_numpy.unpackb(conn.recv())
#      41     return conn, metadata
#
# File ~/PycharmProjects/openpi/packages/openpi-client/.venv/lib/python3.11/site-packages/websockets/sync/client.py:327, in connect(uri, sock, ssl, server_hostname, origin, extensions, subprotocols, compression, additional_headers, user_agent_header, proxy, proxy_ssl, proxy_server_hostname, open_timeout, ping_interval, ping_timeout, close_timeout, max_size, max_queue, logger, create_connection, **kwargs)
#     325     else:
#     326         kwargs.setdefault("timeout", deadline.timeout())
# --> 327         sock = socket.create_connection(
#     328             (ws_uri.host, ws_uri.port),
#     329             **kwargs,
#     330         )
#     331     sock.settimeout(None)
#     333 # Disable Nagle algorithm
#
# File ~/.local/share/uv/python/cpython-3.11.14-linux-x86_64-gnu/lib/python3.11/socket.py:863, in create_connection(address, timeout, source_address, all_errors)
#     861 try:
#     862     if not all_errors:
# --> 863         raise exceptions[0]
#     864     raise ExceptionGroup("create_connection failed", exceptions)
#     865 finally:
#     866     # Break explicitly a reference cycle
#
# File ~/.local/share/uv/python/cpython-3.11.14-linux-x86_64-gnu/lib/python3.11/socket.py:848, in create_connection(address, timeout, source_address, all_errors)
#     846 if source_address:
#     847     sock.bind(source_address)
# --> 848 sock.connect(sa)
#     849 # Break explicitly a reference cycle
#     850 exceptions.clear()
#
# TimeoutError: timed out

# %%
for step in range(num_steps):
    # Inside the episode loop, construct the observation.
    # Resize images on the client side to minimize bandwidth / latency. Always return images in uint8 format.
    # We provide utilities for resizing images + uint8 conversion so you match the training routines.
    # The typical resize_size for pre-trained pi0 models is 224.
    # Note that the proprioceptive `state` can be passed unnormalized, normalization will be handled on the server side.
    observation = {
        "observation/image": image_tools.convert_to_uint8(
            image_tools.resize_with_pad(img, 224, 224)
        ),
        "observation/wrist_image": image_tools.convert_to_uint8(
            image_tools.resize_with_pad(wrist_img, 224, 224)
        ),
        "observation/state": state,
        "prompt": task_instruction,
    }

    # Call the policy server with the current observation.
    # This returns an action chunk of shape (action_horizon, action_dim).
    # Note that you typically only need to call the policy every N steps and execute steps
    # from the predicted action chunk open-loop in the remaining steps.
    action_chunk = client.infer(observation)["actions"]

    # Execute the actions in the environment.
    ...
